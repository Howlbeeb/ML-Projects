# %% [markdown]
# <a href="https://colab.research.google.com/github/Howlbeeb/alx-pre_course/blob/master/SVM_mnist_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version = 1, as_frame= False, cache= True)
X = mnist['data']
y= mnist['target'].astype(np.uint8)

X_train = X[:60000]
y_train = y[:60000]
X_test = X[60000:]
y_test = y[60000:]

# %%
from sklearn.svm import LinearSVC
lin_clf = LinearSVC(random_state=42)
lin_clf.fit(X_train,y_train)
# Out:
# LinearSVC(random_state=42)

# %%
from sklearn.metrics import accuracy_score

y_pred = lin_clf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9169

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.astype(np.float32))
X_test_scaled = scaler.transform(X_test.astype(np.float32))

from sklearn.svm import SVC
svm_clf = SVC(gamma='scale')
svm_clf.fit(X_train_scaled[:10000],y_train[:10000])
# Out:
# SVC()

# %%
y_pred = svm_clf.predict(X_train_scaled)
accuracy_score(y_train, y_pred)
# Out:
# 0.9455333333333333

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform

param_distributions = {'gamma': reciprocal(0.001,0.1), 'C': uniform(1,10)}
rnd_search_cv = RandomizedSearchCV(svm_clf,param_distributions,n_iter=10,verbose = 2, cv=3)
rnd_search_cv.fit(X_train_scaled[:1000],y_train[:1000])
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ....C=4.822440573386529, gamma=0.030132506634655356; total time=   0.7s
# [CV] END ....C=4.822440573386529, gamma=0.030132506634655356; total time=   0.6s
# [CV] END ....C=4.822440573386529, gamma=0.030132506634655356; total time=   0.5s
# [CV] END ....C=5.203262900982688, gamma=0.009588958146016345; total time=   0.5s
# [CV] END ....C=5.203262900982688, gamma=0.009588958146016345; total time=   0.7s
# [CV] END ....C=5.203262900982688, gamma=0.009588958146016345; total time=   0.4s
# [CV] END ...C=4.143156455514102, gamma=0.0024012786731585855; total time=   0.3s
# [CV] END ...C=4.143156455514102, gamma=0.0024012786731585855; total time=   0.3s
# [CV] END ...C=4.143156455514102, gamma=0.0024012786731585855; total time=   0.5s
# [CV] END .....C=5.178733538198434, gamma=0.05716724400647279; total time=   0.6s
# [CV] END .....C=5.178733538198434, gamma=0.05716724400647279; total time=   0.5s
# ...

# %%
rnd_search_cv.best_estimator_
# Out:
# SVC(C=10.879703273628436, gamma=0.0011528411442849216)

# %%
rnd_search_cv.best_score_
# Out:
# 0.8599917282552013

# %%
rnd_search_cv.best_estimator_.fit(X_train_scaled,y_train)
# Out:
# SVC(C=10.879703273628436, gamma=0.0011528411442849216)

# %%
y_pred = rnd_search_cv.best_estimator_.predict(X_train_scaled)
accuracy_score(y_train,y_pred)
# Out:
# 0.9990666666666667

# %%
y_pred = rnd_search_cv.best_estimator_.predict(X_train_scaled)
accuracy_score(y_train,y_pred)
